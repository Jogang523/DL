# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
cd yolov5
# Out:
# c:\Users\M\Documents\GitHub\DL_study\objectdetection\yolov5
# C:\Users\M\AppData\Roaming\Python\Python312\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
pwd
# Out:
# 'c:\\Users\\M\\Documents\\GitHub\\DL_study\\objectdetection\\yolov5'

# %%
# !pip install -r requirements.txt

# %%
cd ..
# Out:
# c:\Users\M\Documents\GitHub\DL_study\objectdetection

# %%
# !git clone https://github.com/ssaru/convert2Yolo.git
# Out:
# Cloning into 'convert2Yolo'...

# %%
cd convert2Yolo
# Out:
# c:\Users\M\Documents\GitHub\DL_study\objectdetection\convert2Yolo

# %%
cd ..
# Out:
# c:\Users\M\Documents\GitHub\DL_study\objectdetection

# %%
import os

# %%
os.mkdir('starbucks')

# %%
cd starbucks
# Out:
# c:\Users\M\Documents\GitHub\DL_study\objectdetection\starbucks

# %%
os.mkdir('data')

# %%
cd data
# Out:
# c:\Users\M\Documents\GitHub\DL_study\objectdetection\starbucks\data

# %%
os.mkdir('images')
os.mkdir('labels')

# %%
cd ../../convert2Yolo/
# Out:
# c:\Users\M\Documents\GitHub\DL_study\objectdetection\convert2Yolo

# %%
# !python example.py --datasets COCO --img_path ../starbucks/data/images \
--label ../starbucks/labels.json --convert_output_path ../starbucks/data/labels \
--img_type ".jpeg" --manifest_path ./
# Out:
# Traceback (most recent call last):
#   File "c:\Users\M\Documents\GitHub\DL_study\objectdetection\convert2Yolo\example.py", line 139, in <module>
#     main(config)
#   File "c:\Users\M\Documents\GitHub\DL_study\objectdetection\convert2Yolo\example.py", line 57, in main
#     flag, data, cls_hierarchy = coco.parse(
#     ^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
pwd
# Out:
# '/content/convert2Yolo'
